# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("status.csv")

# %%
data
# Out:
#      orderId    status
# 0          1  status_b
# 1          2  status_b
# 2          3  status_a
# 3          4  status_a
# 4          5  status_b
# ..       ...       ...
# 265      266  status_b
# 266      267  status_b
# 267      268  status_a
# 268      269  status_b
# 269      270  status_a
#
# [270 rows x 2 columns]

# %%
data1 = pd.read_csv("status_details.csv")

# %%
data1
# Out:
#             Timestamp  orderId  distributorId  originalDistributorId  hubId  \
# 0       13/09/22 2:30       49              1                    1.0    1.0
# 1       13/09/22 2:30      203              1                    1.0    1.0
# 2       13/09/22 2:30      143              1                    1.0    1.0
# 3       13/09/22 2:30      118              1                    1.0    1.0
# 4       13/09/22 2:30      167              1                    1.0    1.0
# ...               ...      ...            ...                    ...    ...
# 11796  13/09/22 13:48      211             14                   30.0    4.0
# 11797  13/09/22 13:48       81             14                   28.0    4.0
# 11798  13/09/22 13:48       96             14                   43.0    4.0
# 11799  13/09/22 13:48      237             14                   33.0    4.0
# 11800  13/09/22 14:42      172             14                   44.0    4.0
#
# ...

# %%
df = pd.merge(data, data1, how = "inner", on = ['orderId'])

# %%
df
# Out:
#        orderId    status       Timestamp  distributorId  \
# 0            1  status_b   13/09/22 2:30              1
# 1            1  status_b   13/09/22 2:30              1
# 2            1  status_b   13/09/22 2:30              1
# 3            1  status_b   13/09/22 2:38              2
# 4            1  status_b   13/09/22 2:38              2
# ...        ...       ...             ...            ...
# 11796      270  status_a  13/09/22 10:34             27
# 11797      270  status_a  13/09/22 11:08             15
# 11798      270  status_a  13/09/22 11:56              8
# 11799      270  status_a  13/09/22 12:33              5
# 11800      270  status_a  13/09/22 12:56              2
#
#        originalDistributorId  hubId  quantity    Amount hubCode  Unnamed: 8  \
# 0                        1.0    1.0        13   1487.04       a         NaN
# 1                        1.0    1.0         7   1205.58       a         NaN
# ...

# %%
df.drop(['Unnamed: 10','Unnamed: 9','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 8'], axis = 1)
# Out:
#        orderId    status       Timestamp  distributorId  \
# 0            1  status_b   13/09/22 2:30              1
# 1            1  status_b   13/09/22 2:30              1
# 2            1  status_b   13/09/22 2:30              1
# 3            1  status_b   13/09/22 2:38              2
# 4            1  status_b   13/09/22 2:38              2
# ...        ...       ...             ...            ...
# 11796      270  status_a  13/09/22 10:34             27
# 11797      270  status_a  13/09/22 11:08             15
# 11798      270  status_a  13/09/22 11:56              8
# 11799      270  status_a  13/09/22 12:33              5
# 11800      270  status_a  13/09/22 12:56              2
#
#        originalDistributorId  hubId  quantity    Amount hubCode
# 0                        1.0    1.0        13   1487.04       a
# 1                        1.0    1.0         7   1205.58       a
# 2                        1.0    1.0         2    535.50       a
# ...

# %%
df.to_csv('STATUS_PROJECT.csv')
